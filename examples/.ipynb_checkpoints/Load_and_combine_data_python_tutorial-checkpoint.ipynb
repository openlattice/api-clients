# %% [markdown]
# # OpenLattice Python API tutorial
#
# This notebook shows how to use the open API documentation to interact with the OpenLattice backend, and load and join data for analysis with python.

# %% [markdown]
# After we've installed the python library for the OL-API, we can load the library, set the basepath and our authentication, and get the client. You can find you jwt token in the [**account page**](https://openlattice.com/gallery/#/home) of your openlattice account

# %%
import openlattice
import numpy as np
import pandas as pd

jwt = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....Wb21KCj1MDu2zsFA1l6g_UhI1AvvksrDPHWE97IYmyo"

baseurl = 'https://api.openlattice.com'

configuration = openlattice.Configuration()
configuration.host = baseurl
configuration.api_key_prefix['Authorization'] = 'Bearer'
configuration.api_key['Authorization'] = jwt

# %% [markdown]
# In this notebook, we'll use the edmAPI (to find the details of the entity sets), the dataAPI (to load the data) and the searchAPI (to search the neighbors).

# %%
edmAPI = openlattice.EdmApi(openlattice.ApiClient(configuration))
dataAPI = openlattice.DataApi(openlattice.ApiClient(configuration))
searchAPI = openlattice.SearchApi(openlattice.ApiClient(configuration))

# %% [markdown]
# ## Get original data and data from localhost

# %% [markdown]
# We now load the entity set IDs and the data. First, we decide what data we want.  Let's say we have integrated data from a sheriff's office, supportive housing group, and detox center. We want to look at arrestees and any housing statuses they've given in the past. Use your flight diagrams to decide upon entity sets and relationships and get their names: from your OpenLattice integration, you should have a diagram of the graph data model that your data now resides in. The one for our healthcare demonstration data is [here](https://github.com/Lattice-Works/api-clients/examples/demohealth.pdf).

# %% [markdown]
# We can see that **DemoPatients -> DemoLivesAt -> DemoHousings** gives us people and any housing status associated with them. Let's say you linked sheriff and health data in a new person dataset called **"DemoLinkedPeople2"**. We know that by calling upon the linked people we can include those arrested.
#
# First, we get the entitysetid's for the datasets we want. The documentation for the edmAPI can be found here: https://github.com/Lattice-Works/datascience-tools/blob/master/api-clients/python/docs/EdmApi.md
# It lists all functions with a description. We will use the function get_entity_set_id(). If you click on that function, it shows which parameters should be added. In this case the parameters are entity_set_name, which is a string.

# %%
sourceEntitySetId = edmAPI.get_entity_set_id('DemoLinkedPeople2')
associationEntitySetId = edmAPI.get_entity_set_id('DemoLivesAt')
destEntitySetId = edmAPI.get_entity_set_id('DemoHousings')

# %% [markdown]
# With the dataAPI, we can load the data.  We can immediately read them into a pandas DataFrame.  Then we set the index to the **first** `openlattice.@id`.

# %%
src_data = pd.DataFrame(dataAPI.load_entity_set_data(sourceEntitySetId))
edge_data = pd.DataFrame(dataAPI.load_entity_set_data(associationEntitySetId))
dst_data = pd.DataFrame(dataAPI.load_entity_set_data(destEntitySetId))

# %%
# removing property multiplicity (get first entry)
for column in src_data.columns:
    src_data[column] = [x[0] if isinstance(x, list) else None for x in src_data[column]]
for column in edge_data.columns:
    edge_data[column] = [x[0] if isinstance(x, list) else None for x in edge_data[column]]
for column in dst_data.columns:
    dst_data[column] = [x[0] if isinstance(x, list) else None for x in dst_data[column]]

src_data = src_data.set_index('openlattice.@id', drop = True).dropna(how='all')
dst_data = dst_data.set_index('openlattice.@id', drop = True).dropna(how='all')
edge_data = edge_data.set_index('openlattice.@id', drop = True).dropna(how='all')

# %% [markdown]
# ### Show heads of entity sets

# %%
src_data.head(5)
# Out:
#                                      nc.PersonBirthDate nc.PersonEthnicity  \
# openlattice.@id
# 003b0000-0000-0000-8000-0000000020d7         1955-12-28        nonhispanic
# 00e40000-0000-0000-8000-00000000207e         1981-01-15        nonhispanic
# 01140000-0000-0000-8000-000000003159         1953-01-03        nonhispanic
# 02a80000-0000-0000-8000-0000000020e8         1967-03-20        nonhispanic
# 03810000-0000-0000-8000-0000000035cb         1996-08-14           hispanic
#
#                                      nc.PersonGivenName nc.PersonRace  \
# openlattice.@id
# 003b0000-0000-0000-8000-0000000020d7               Jose         white
# 00e40000-0000-0000-8000-00000000207e               Jose         white
# 01140000-0000-0000-8000-000000003159               Anna         white
# 02a80000-0000-0000-8000-0000000020e8             Tamara         asian
# 03810000-0000-0000-8000-0000000035cb            Caitlyn         white
#
#                                      nc.PersonSex nc.PersonSurName  \
# openlattice.@id
# 003b0000-0000-0000-8000-0000000020d7            M          Calhoun
# 00e40000-0000-0000-8000-00000000207e            M            Kelly
# 01140000-0000-0000-8000-000000003159            F           Patton
# 02a80000-0000-0000-8000-0000000020e8            F             Koch
# 03810000-0000-0000-8000-0000000035cb            F          Swanson
#
#                                                   nc.SubjectIdentification  \
# openlattice.@id
# 003b0000-0000-0000-8000-0000000020d7  6dee78dc-aa81-4020-8c23-a44f6ccb7de2
# 00e40000-0000-0000-8000-00000000207e  b16e1e68-1919-4409-94cf-514b32596040
# 01140000-0000-0000-8000-000000003159  a125db71-4299-4c02-9133-316c6b135108
# 02a80000-0000-0000-8000-0000000020e8  ba086259-551e-4764-be3c-a3a44d34de92
# 03810000-0000-0000-8000-0000000035cb  8f319acd-0366-4320-9c65-f9bb4ca12547
#
#                                                     ol.datasource
# openlattice.@id
# 003b0000-0000-0000-8000-0000000020d7           Any County Sheriff
# 00e40000-0000-0000-8000-00000000207e         Anytown Police Dept.
# 01140000-0000-0000-8000-000000003159         Anytown Police Dept.
# 02a80000-0000-0000-8000-0000000020e8  Forest Outpatient Treatment
# 03810000-0000-0000-8000-0000000035cb         Anytown Police Dept.

# %%
dst_data.head(5)
# Out:
#                                                       ol.id  \
# openlattice.@id
# cef20000-0000-0000-8000-0000000032a9     INDEPENDENT LIVING
# d5000000-0000-0000-8000-000000003234               HOMELESS
# 34490000-0000-0000-8000-0000000032ee       DEPENDENT LIVING
# 608b0000-0000-0000-8000-0000000031d0  RECENTLY INCARCERATED
# 74210000-0000-0000-8000-00000000325b             SOBER HOME
#
#                                                     ol.type
# openlattice.@id
# cef20000-0000-0000-8000-0000000032a9     INDEPENDENT LIVING
# d5000000-0000-0000-8000-000000003234               HOMELESS
# 34490000-0000-0000-8000-0000000032ee       DEPENDENT LIVING
# 608b0000-0000-0000-8000-0000000031d0  RECENTLY INCARCERATED
# 74210000-0000-0000-8000-00000000325b             SOBER HOME

# %%
edge_data.head(5)
# Out:
#                                                                              general.id
# openlattice.@id
# 1f510000-0000-0000-8000-000000003195  852f2853-1f11-425d-9a34-a23b051a6ccf_INDEPENDE...
# d7c80000-0000-0000-8000-00000000323f      4f304f4a-a022-4903-a34b-e67901076b54_HOMELESS
# 95d40000-0000-0000-8000-000000003216    34822c97-4a6f-4442-90bb-e647a989189f_SOBER HOME
# 0bb50000-0000-0000-8000-00000000326c  29c67c2e-1b11-4141-b7e2-909387096eb9_RECENTLY ...
# 92e50000-0000-0000-8000-00000000321d  15586b2e-08e0-424f-a60e-d365ed0650e1_INDEPENDE...

# %% [markdown]
# ## Search the links between the entity sets with the API
#
# ### Full search (execute_entity_neighbor_search)

# %% [markdown]
# To join two entity sets (through an edge/association) we must find the unique ID that each data point, or entity, has in the three tables: the source, destination, and association. We call these IDs the neighbors.
#
# The `execute_entity_neighbor_search`-function allows us to find all neighbors of an entity.  We can find the neighbors of the first entity in the data with the following arguments:
#
# **note:** `src_data.index` is the index of the table: the entity_keys of this entity set)

# %%
searchAPI.execute_entity_neighbor_search(sourceEntitySetId, src_data.index[0])
# Out:
# [{'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_20-01565']",
#                           'openlattice_id': "['e9a50000-0000-0000-8000-00000000319c']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '34aeaca4-d424-43cd-a3b4-f2032d583280',
#                              'external': True,
#                              'id': 'e3bb770c-156b-4227-b1d6-daa1786740df',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSubjectOf',
#                              'title': 'Demo: SubjectOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Arrest events. Information is '
#                                          'synthetic and for demo purposes only.',
#                           'entity_type_id': 'a8933914-d849-4b90-ab0f-eaa1525c4ec8',
#                           'external': True,
#                           'id': 'e591337f-255e-4a42-a540-bc43e117b09d',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoArrests',
#                           'title': 'Demo: Arrests'},
#   'neighbor_id': '6b360000-0000-0000-8000-0000000030f5',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_2016-94847']",
#                           'openlattice_id': "['00880000-0000-0000-8000-0000000030fb']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '5bf88cde-65bc-4865-a58b-920eec4c4028',
#                              'external': True,
#                              'id': '6405cd23-e95f-488d-bfe1-2c937e9adca8',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoInvolvedIn',
#                              'title': 'Demo: InvolvedIn'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Incidents in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '72dc4594-8dc0-4956-959f-2408a069f2aa',
#                           'external': True,
#                           'id': 'c60edffb-a86c-4911-b0eb-1ab7495cf710',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoIncidents',
#                           'title': 'Demo: Incidents'},
#   'neighbor_id': '04080000-0000-0000-8000-0000000030f1',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_4700']",
#                           'openlattice_id': "['88c20000-0000-0000-8000-000000003181']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'a094e89f-3b4f-4e98-9d2c-12e604ae9d6a',
#                              'external': True,
#                              'id': 'c06b638f-550d-4fdf-a544-683e0afdf381',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoReleasedBy',
#                              'title': 'Demo: ReleasedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Police officers in the OpenLattice '
#                                          'demo data. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': '6a970000-0000-0000-8000-0000000030e6',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_70434']",
#                           'openlattice_id': "['63ba0000-0000-0000-8000-00000000317b']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '34aeaca4-d424-43cd-a3b4-f2032d583280',
#                              'external': True,
#                              'id': 'e3bb770c-156b-4227-b1d6-daa1786740df',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSubjectOf',
#                              'title': 'Demo: SubjectOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Demo bookings. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '42c87ead-3038-4682-961c-5dd079071786',
#                           'external': True,
#                           'id': '43b8331a-71f0-46a4-afbd-4e5ebc416321',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoBookings',
#                           'title': 'Demo: Bookings'},
#   'neighbor_id': '4a680000-0000-0000-8000-0000000031ec',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': None,
#                           'openlattice_id': "['a4df0000-0000-0000-8000-0000000031b1']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'ecc09e28-0761-4ed0-9d9e-b1c1f883aed6',
#                              'external': True,
#                              'id': 'ce0f6389-37bf-4713-b511-b5ac00660213',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoLocatedAt',
#                              'title': 'Demo: LocatedAt'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Locations/addresses in the '
#                                          'OpenLattice demo data. This '
#                                          'information is synthetic and for '
#                                          'demonstration purposes only.',
#                           'entity_type_id': '136eee13-0113-4b91-a804-6154824daa49',
#                           'external': True,
#                           'id': 'cc035cb5-1a37-4e35-87e9-cbf3aba9abb4',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoLocations',
#                           'title': 'Demo: Locations'},
#   'neighbor_id': '35560000-0000-0000-8000-000000003189',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': None,
#                           'openlattice_id': "['0d4d0000-0000-0000-8000-00000000310a']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '22f294e5-f3f4-4317-8ff8-63528125c95f',
#                              'external': True,
#                              'id': '1fd760dd-d8e5-4fac-b87f-19858fa34134',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoChargedWith',
#                              'title': 'Demo: ChargedWith'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Charges that people may be charged '
#                                          'with in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'd038e8f6-5910-46b2-88e4-b028a5120a46',
#                           'external': True,
#                           'id': '60af43c1-f692-4f64-9329-3ebc7c677a71',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoCharges',
#                           'title': 'Demo: Charges'},
#   'neighbor_id': 'ca810000-0000-0000-8000-0000000031d9',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': None,
#                           'openlattice_id': "['07960000-0000-0000-8000-0000000031b1']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'ecc09e28-0761-4ed0-9d9e-b1c1f883aed6',
#                              'external': True,
#                              'id': 'ce0f6389-37bf-4713-b511-b5ac00660213',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoLocatedAt',
#                              'title': 'Demo: LocatedAt'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Locations/addresses in the '
#                                          'OpenLattice demo data. This '
#                                          'information is synthetic and for '
#                                          'demonstration purposes only.',
#                           'entity_type_id': '136eee13-0113-4b91-a804-6154824daa49',
#                           'external': True,
#                           'id': 'cc035cb5-1a37-4e35-87e9-cbf3aba9abb4',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoLocations',
#                           'title': 'Demo: Locations'},
#   'neighbor_id': 'b6b20000-0000-0000-8000-000000003125',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_2014-48942']",
#                           'openlattice_id': "['9d020000-0000-0000-8000-0000000031d7']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '5bf88cde-65bc-4865-a58b-920eec4c4028',
#                              'external': True,
#                              'id': '6405cd23-e95f-488d-bfe1-2c937e9adca8',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoInvolvedIn',
#                              'title': 'Demo: InvolvedIn'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Incidents in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '72dc4594-8dc0-4956-959f-2408a069f2aa',
#                           'external': True,
#                           'id': 'c60edffb-a86c-4911-b0eb-1ab7495cf710',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoIncidents',
#                           'title': 'Demo: Incidents'},
#   'neighbor_id': '097b0000-0000-0000-8000-000000003146',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_20-00289']",
#                           'openlattice_id': "['81670000-0000-0000-8000-0000000031a7']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '34aeaca4-d424-43cd-a3b4-f2032d583280',
#                              'external': True,
#                              'id': 'e3bb770c-156b-4227-b1d6-daa1786740df',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSubjectOf',
#                              'title': 'Demo: SubjectOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Arrest events. Information is '
#                                          'synthetic and for demo purposes only.',
#                           'entity_type_id': 'a8933914-d849-4b90-ab0f-eaa1525c4ec8',
#                           'external': True,
#                           'id': 'e591337f-255e-4a42-a540-bc43e117b09d',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoArrests',
#                           'title': 'Demo: Arrests'},
#   'neighbor_id': 'dd290000-0000-0000-8000-000000003142',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_20-01754']",
#                           'openlattice_id': "['800f0000-0000-0000-8000-000000003132']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '34aeaca4-d424-43cd-a3b4-f2032d583280',
#                              'external': True,
#                              'id': 'e3bb770c-156b-4227-b1d6-daa1786740df',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSubjectOf',
#                              'title': 'Demo: SubjectOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Arrest events. Information is '
#                                          'synthetic and for demo purposes only.',
#                           'entity_type_id': 'a8933914-d849-4b90-ab0f-eaa1525c4ec8',
#                           'external': True,
#                           'id': 'e591337f-255e-4a42-a540-bc43e117b09d',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoArrests',
#                           'title': 'Demo: Arrests'},
#   'neighbor_id': 'cd530000-0000-0000-8000-0000000031dc',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_2015-75717']",
#                           'openlattice_id': "['9a610000-0000-0000-8000-00000000315e']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '5bf88cde-65bc-4865-a58b-920eec4c4028',
#                              'external': True,
#                              'id': '6405cd23-e95f-488d-bfe1-2c937e9adca8',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoInvolvedIn',
#                              'title': 'Demo: InvolvedIn'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Incidents in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '72dc4594-8dc0-4956-959f-2408a069f2aa',
#                           'external': True,
#                           'id': 'c60edffb-a86c-4911-b0eb-1ab7495cf710',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoIncidents',
#                           'title': 'Demo: Incidents'},
#   'neighbor_id': '571e0000-0000-0000-8000-00000000311f',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_2160']",
#                           'openlattice_id': "['f8ab0000-0000-0000-8000-0000000031b2']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': 'An officer transporting an '
#                                             'individual in the OpenLattice demo '
#                                             'data. This information is '
#                                             'synthetic and for demonstration '
#                                             'purposes only.',
#                              'entity_type_id': 'a404cc39-0259-4c8e-91b5-8def2071d997',
#                              'external': True,
#                              'id': 'c149f00a-2c00-4b84-9d23-89a6ed93ee3e',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoTransportedBy',
#                              'title': 'Demo: TransportedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Police officers in the OpenLattice '
#                                          'demo data. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': '53fa0000-0000-0000-8000-000000003170',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_18928']",
#                           'openlattice_id': "['f6350000-0000-0000-8000-000000003176']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'a4da94ce-450e-4740-87a0-ef05d57597c6',
#                              'external': True,
#                              'id': 'b7bcc6f1-7b8d-470b-8b68-1485dc61cb5e',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSuspectedOf',
#                              'title': 'Demo: SuspectedOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Offenses that lead to the arrest of '
#                                          'suspects in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '33f389fe-9ff6-41eb-b7f9-aa1aad545014',
#                           'external': True,
#                           'id': 'cc5a3ede-884a-4565-93a7-5acf8dafcbbb',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOffenses',
#                           'title': 'Demo: Offenses'},
#   'neighbor_id': '575b0000-0000-0000-8000-0000000030ac',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': None,
#                           'openlattice_id': "['9af00000-0000-0000-8000-000000003124']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'ecc09e28-0761-4ed0-9d9e-b1c1f883aed6',
#                              'external': True,
#                              'id': 'ce0f6389-37bf-4713-b511-b5ac00660213',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoLocatedAt',
#                              'title': 'Demo: LocatedAt'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Locations/addresses in the '
#                                          'OpenLattice demo data. This '
#                                          'information is synthetic and for '
#                                          'demonstration purposes only.',
#                           'entity_type_id': '136eee13-0113-4b91-a804-6154824daa49',
#                           'external': True,
#                           'id': 'cc035cb5-1a37-4e35-87e9-cbf3aba9abb4',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoLocations',
#                           'title': 'Demo: Locations'},
#   'neighbor_id': 'a8920000-0000-0000-8000-000000003101',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_2014-23521']",
#                           'openlattice_id': "['2f890000-0000-0000-8000-000000003139']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '5bf88cde-65bc-4865-a58b-920eec4c4028',
#                              'external': True,
#                              'id': '6405cd23-e95f-488d-bfe1-2c937e9adca8',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoInvolvedIn',
#                              'title': 'Demo: InvolvedIn'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Incidents in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '72dc4594-8dc0-4956-959f-2408a069f2aa',
#                           'external': True,
#                           'id': 'c60edffb-a86c-4911-b0eb-1ab7495cf710',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoIncidents',
#                           'title': 'Demo: Incidents'},
#   'neighbor_id': '0db30000-0000-0000-8000-000000003144',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_5809']",
#                           'openlattice_id': "['362b0000-0000-0000-8000-0000000031e8']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'edaca5dc-9255-460a-8013-e31ace5723db',
#                              'external': True,
#                              'id': 'fd3ad532-e48b-409f-97cf-d3e73326b8e0',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoArrestedBy',
#                              'title': 'Demo: ArrestedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Police officers in the OpenLattice '
#                                          'demo data. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': '91590000-0000-0000-8000-0000000031c1',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_59123']",
#                           'openlattice_id': "['2e9e0000-0000-0000-8000-0000000030f9']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '34aeaca4-d424-43cd-a3b4-f2032d583280',
#                              'external': True,
#                              'id': 'e3bb770c-156b-4227-b1d6-daa1786740df',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSubjectOf',
#                              'title': 'Demo: SubjectOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Demo bookings. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '42c87ead-3038-4682-961c-5dd079071786',
#                           'external': True,
#                           'id': '43b8331a-71f0-46a4-afbd-4e5ebc416321',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoBookings',
#                           'title': 'Demo: Bookings'},
#   'neighbor_id': 'd0200000-0000-0000-8000-0000000031bd',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_2014-40386']",
#                           'openlattice_id': "['ccad0000-0000-0000-8000-00000000311b']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '5bf88cde-65bc-4865-a58b-920eec4c4028',
#                              'external': True,
#                              'id': '6405cd23-e95f-488d-bfe1-2c937e9adca8',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoInvolvedIn',
#                              'title': 'Demo: InvolvedIn'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Incidents in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '72dc4594-8dc0-4956-959f-2408a069f2aa',
#                           'external': True,
#                           'id': 'c60edffb-a86c-4911-b0eb-1ab7495cf710',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoIncidents',
#                           'title': 'Demo: Incidents'},
#   'neighbor_id': '3daa0000-0000-0000-8000-00000000312d',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_4258']",
#                           'openlattice_id': "['5f480000-0000-0000-8000-0000000031a3']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'a094e89f-3b4f-4e98-9d2c-12e604ae9d6a',
#                              'external': True,
#                              'id': 'c06b638f-550d-4fdf-a544-683e0afdf381',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoReleasedBy',
#                              'title': 'Demo: ReleasedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Police officers in the OpenLattice '
#                                          'demo data. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': 'e5260000-0000-0000-8000-000000003093',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': None,
#                           'openlattice_id': "['6d6f0000-0000-0000-8000-000000003263']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '22f294e5-f3f4-4317-8ff8-63528125c95f',
#                              'external': True,
#                              'id': '1fd760dd-d8e5-4fac-b87f-19858fa34134',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoChargedWith',
#                              'title': 'Demo: ChargedWith'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Charges that people may be charged '
#                                          'with in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'd038e8f6-5910-46b2-88e4-b028a5120a46',
#                           'external': True,
#                           'id': '60af43c1-f692-4f64-9329-3ebc7c677a71',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoCharges',
#                           'title': 'Demo: Charges'},
#   'neighbor_id': '47980000-0000-0000-8000-00000000312b',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': None,
#                           'openlattice_id': "['ee530000-0000-0000-8000-0000000031b3']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '22f294e5-f3f4-4317-8ff8-63528125c95f',
#                              'external': True,
#                              'id': '1fd760dd-d8e5-4fac-b87f-19858fa34134',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoChargedWith',
#                              'title': 'Demo: ChargedWith'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Charges that people may be charged '
#                                          'with in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'd038e8f6-5910-46b2-88e4-b028a5120a46',
#                           'external': True,
#                           'id': '60af43c1-f692-4f64-9329-3ebc7c677a71',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoCharges',
#                           'title': 'Demo: Charges'},
#   'neighbor_id': 'fafb0000-0000-0000-8000-00000000318f',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': None,
#                           'openlattice_id': "['37630000-0000-0000-8000-000000003096']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'ecc09e28-0761-4ed0-9d9e-b1c1f883aed6',
#                              'external': True,
#                              'id': 'ce0f6389-37bf-4713-b511-b5ac00660213',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoLocatedAt',
#                              'title': 'Demo: LocatedAt'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Locations/addresses in the '
#                                          'OpenLattice demo data. This '
#                                          'information is synthetic and for '
#                                          'demonstration purposes only.',
#                           'entity_type_id': '136eee13-0113-4b91-a804-6154824daa49',
#                           'external': True,
#                           'id': 'cc035cb5-1a37-4e35-87e9-cbf3aba9abb4',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoLocations',
#                           'title': 'Demo: Locations'},
#   'neighbor_id': '21f00000-0000-0000-8000-000000003101',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_5735']",
#                           'openlattice_id': "['9e0b0000-0000-0000-8000-00000000316f']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'a094e89f-3b4f-4e98-9d2c-12e604ae9d6a',
#                              'external': True,
#                              'id': 'c06b638f-550d-4fdf-a544-683e0afdf381',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoReleasedBy',
#                              'title': 'Demo: ReleasedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Police officers in the OpenLattice '
#                                          'demo data. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': '67e30000-0000-0000-8000-0000000030fe',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_3774']",
#                           'openlattice_id': "['fe5e0000-0000-0000-8000-00000000318b']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'edaca5dc-9255-460a-8013-e31ace5723db',
#                              'external': True,
#                              'id': 'fd3ad532-e48b-409f-97cf-d3e73326b8e0',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoArrestedBy',
#                              'title': 'Demo: ArrestedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Police officers in the OpenLattice '
#                                          'demo data. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': '724e0000-0000-0000-8000-00000000311d',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_83778']",
#                           'openlattice_id': "['cce70000-0000-0000-8000-0000000031b7']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '34aeaca4-d424-43cd-a3b4-f2032d583280',
#                              'external': True,
#                              'id': 'e3bb770c-156b-4227-b1d6-daa1786740df',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSubjectOf',
#                              'title': 'Demo: SubjectOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Demo bookings. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '42c87ead-3038-4682-961c-5dd079071786',
#                           'external': True,
#                           'id': '43b8331a-71f0-46a4-afbd-4e5ebc416321',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoBookings',
#                           'title': 'Demo: Bookings'},
#   'neighbor_id': 'ec1c0000-0000-0000-8000-000000003160',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_Anytown "
#                                    "Police Dept.']",
#                           'openlattice_id': "['2e240000-0000-0000-8000-000000003129']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'edaca5dc-9255-460a-8013-e31ace5723db',
#                              'external': True,
#                              'id': 'fd3ad532-e48b-409f-97cf-d3e73326b8e0',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoArrestedBy',
#                              'title': 'Demo: ArrestedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Agencies that make arrests in the '
#                                          'OpenLattice demo data. This '
#                                          'information is synthetic and for '
#                                          'demonstration purposes only.',
#                           'entity_type_id': 'e33ad963-60fd-489d-8cdb-9faca522e18a',
#                           'external': True,
#                           'id': 'f1d03764-a086-46da-b8fd-6f99dfd623f7',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoArrestingAgency',
#                           'title': 'Demo: ArrestingAgencies'},
#   'neighbor_id': '54bc0000-0000-0000-8000-000000003127',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_70590']",
#                           'openlattice_id': "['afce0000-0000-0000-8000-000000003141']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'a4da94ce-450e-4740-87a0-ef05d57597c6',
#                              'external': True,
#                              'id': 'b7bcc6f1-7b8d-470b-8b68-1485dc61cb5e',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSuspectedOf',
#                              'title': 'Demo: SuspectedOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Offenses that lead to the arrest of '
#                                          'suspects in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '33f389fe-9ff6-41eb-b7f9-aa1aad545014',
#                           'external': True,
#                           'id': 'cc5a3ede-884a-4565-93a7-5acf8dafcbbb',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOffenses',
#                           'title': 'Demo: Offenses'},
#   'neighbor_id': '2d690000-0000-0000-8000-00000000313c',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_2172']",
#                           'openlattice_id': "['7f850000-0000-0000-8000-00000000315b']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'a094e89f-3b4f-4e98-9d2c-12e604ae9d6a',
#                              'external': True,
#                              'id': 'c06b638f-550d-4fdf-a544-683e0afdf381',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoReleasedBy',
#                              'title': 'Demo: ReleasedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Police officers in the OpenLattice '
#                                          'demo data. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': '814a0000-0000-0000-8000-000000003152',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_5865']",
#                           'openlattice_id': "['fca40000-0000-0000-8000-000000003165']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': 'An officer transporting an '
#                                             'individual in the OpenLattice demo '
#                                             'data. This information is '
#                                             'synthetic and for demonstration '
#                                             'purposes only.',
# ...
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': '39a70000-0000-0000-8000-0000000031cd',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': None,
#                           'openlattice_id': "['42d90000-0000-0000-8000-00000000312a']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '22f294e5-f3f4-4317-8ff8-63528125c95f',
#                              'external': True,
#                              'id': '1fd760dd-d8e5-4fac-b87f-19858fa34134',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoChargedWith',
#                              'title': 'Demo: ChargedWith'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Charges that people may be charged '
#                                          'with in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'd038e8f6-5910-46b2-88e4-b028a5120a46',
#                           'external': True,
#                           'id': '60af43c1-f692-4f64-9329-3ebc7c677a71',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoCharges',
#                           'title': 'Demo: Charges'},
#   'neighbor_id': 'd12b0000-0000-0000-8000-0000000031d9',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_90350']",
#                           'openlattice_id': "['d5840000-0000-0000-8000-00000000314e']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'a4da94ce-450e-4740-87a0-ef05d57597c6',
#                              'external': True,
#                              'id': 'b7bcc6f1-7b8d-470b-8b68-1485dc61cb5e',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSuspectedOf',
#                              'title': 'Demo: SuspectedOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Offenses that lead to the arrest of '
#                                          'suspects in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '33f389fe-9ff6-41eb-b7f9-aa1aad545014',
#                           'external': True,
#                           'id': 'cc5a3ede-884a-4565-93a7-5acf8dafcbbb',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOffenses',
#                           'title': 'Demo: Offenses'},
#   'neighbor_id': 'e8500000-0000-0000-8000-000000003075',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_2828']",
#                           'openlattice_id': "['641e0000-0000-0000-8000-0000000031d1']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'edaca5dc-9255-460a-8013-e31ace5723db',
#                              'external': True,
#                              'id': 'fd3ad532-e48b-409f-97cf-d3e73326b8e0',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoArrestedBy',
#                              'title': 'Demo: ArrestedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Police officers in the OpenLattice '
#                                          'demo data. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': 'f73f0000-0000-0000-8000-0000000030e6',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_20-00599']",
#                           'openlattice_id': "['59820000-0000-0000-8000-000000003134']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '34aeaca4-d424-43cd-a3b4-f2032d583280',
#                              'external': True,
#                              'id': 'e3bb770c-156b-4227-b1d6-daa1786740df',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSubjectOf',
#                              'title': 'Demo: SubjectOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Arrest events. Information is '
#                                          'synthetic and for demo purposes only.',
#                           'entity_type_id': 'a8933914-d849-4b90-ab0f-eaa1525c4ec8',
#                           'external': True,
#                           'id': 'e591337f-255e-4a42-a540-bc43e117b09d',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoArrests',
#                           'title': 'Demo: Arrests'},
#   'neighbor_id': 'df800000-0000-0000-8000-00000000310a',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_1348']",
#                           'openlattice_id': "['74760000-0000-0000-8000-000000003238']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': 'An officer transporting an '
#                                             'individual in the OpenLattice demo '
#                                             'data. This information is '
#                                             'synthetic and for demonstration '
#                                             'purposes only.',
#                              'entity_type_id': 'a404cc39-0259-4c8e-91b5-8def2071d997',
#                              'external': True,
#                              'id': 'c149f00a-2c00-4b84-9d23-89a6ed93ee3e',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoTransportedBy',
#                              'title': 'Demo: TransportedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Police officers in the OpenLattice '
#                                          'demo data. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': '340a0000-0000-0000-8000-0000000030ee',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_20-01326']",
#                           'openlattice_id': "['fa680000-0000-0000-8000-000000003112']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': '34aeaca4-d424-43cd-a3b4-f2032d583280',
#                              'external': True,
#                              'id': 'e3bb770c-156b-4227-b1d6-daa1786740df',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSubjectOf',
#                              'title': 'Demo: SubjectOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Arrest events. Information is '
#                                          'synthetic and for demo purposes only.',
#                           'entity_type_id': 'a8933914-d849-4b90-ab0f-eaa1525c4ec8',
#                           'external': True,
#                           'id': 'e591337f-255e-4a42-a540-bc43e117b09d',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoArrests',
#                           'title': 'Demo: Arrests'},
#   'neighbor_id': '61a70000-0000-0000-8000-0000000030cf',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_4868']",
#                           'openlattice_id': "['17360000-0000-0000-8000-00000000314f']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'edaca5dc-9255-460a-8013-e31ace5723db',
#                              'external': True,
#                              'id': 'fd3ad532-e48b-409f-97cf-d3e73326b8e0',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoArrestedBy',
#                              'title': 'Demo: ArrestedBy'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Police officers in the OpenLattice '
#                                          'demo data. This information is '
#                                          'synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': 'f32f0c3e-ed80-4155-89b6-0baaba21eaee',
#                           'external': True,
#                           'id': '90616578-ec36-4e97-877f-77566fac25e6',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOfficers',
#                           'title': 'Demo: Officers'},
#   'neighbor_id': '2c910000-0000-0000-8000-00000000314d',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': None,
#                           'openlattice_id': "['03dc0000-0000-0000-8000-0000000031eb']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'ecc09e28-0761-4ed0-9d9e-b1c1f883aed6',
#                              'external': True,
#                              'id': 'ce0f6389-37bf-4713-b511-b5ac00660213',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoLocatedAt',
#                              'title': 'Demo: LocatedAt'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Locations/addresses in the '
#                                          'OpenLattice demo data. This '
#                                          'information is synthetic and for '
#                                          'demonstration purposes only.',
#                           'entity_type_id': '136eee13-0113-4b91-a804-6154824daa49',
#                           'external': True,
#                           'id': 'cc035cb5-1a37-4e35-87e9-cbf3aba9abb4',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoLocations',
#                           'title': 'Demo: Locations'},
#   'neighbor_id': 'da610000-0000-0000-8000-0000000031a6',
#   'neighbour_details': None},
#  {'association_details': {'ol_id': "['6dee78dc-aa81-4020-8c23-a44f6ccb7de2_76416']",
#                           'openlattice_id': "['84c00000-0000-0000-8000-0000000030f8']"},
#   'association_entity_set': {'contacts': ['kim@openlattice.com',
#                                           'jason@openlattice.com'],
#                              'description': '',
#                              'entity_type_id': 'a4da94ce-450e-4740-87a0-ef05d57597c6',
#                              'external': True,
#                              'id': 'b7bcc6f1-7b8d-470b-8b68-1485dc61cb5e',
#                              'linked_entity_sets': None,
#                              'linking': False,
#                              'name': 'DemoSuspectedOf',
#                              'title': 'Demo: SuspectedOf'},
#   'neighbor_entity_set': {'contacts': ['kim@openlattice.com',
#                                        'jason@openlattice.com'],
#                           'description': 'Offenses that lead to the arrest of '
#                                          'suspects in the OpenLattice criminal '
#                                          'justice demo data. This information '
#                                          'is synthetic and for demonstration '
#                                          'purposes only.',
#                           'entity_type_id': '33f389fe-9ff6-41eb-b7f9-aa1aad545014',
#                           'external': True,
#                           'id': 'cc5a3ede-884a-4565-93a7-5acf8dafcbbb',
#                           'linked_entity_sets': None,
#                           'linking': False,
#                           'name': 'DemoOffenses',
#                           'title': 'Demo: Offenses'},
#   'neighbor_id': '04ca0000-0000-0000-8000-000000003182',
#   'neighbour_details': None}]

# %% [markdown]
# ### Filtered search (execute_filtered_entity_neighbor_search)

# %% [markdown]
# With the filtered search, we can be more specific about the source, destination and association. To make such a query, we need to instantiate an object of type `openapi_client.NeighborSearchFilter`.  Note that we will give the source_entity_set_id in the search function, so we leave it as an empty list here in the object.
#
# We will only search for the first 10 entities of the source data for easier viewing.
#
# **Always set the _other_ entity set (whether source or destination) to a blank.**

# %%
neighbor_filter = openlattice.NeighborSearchFilter(
    edge = [associationEntitySetId],
    src = [],
    dst = [destEntitySetId],
    entity_key_ids = src_data.index.tolist()[:10]
)

# %% [markdown]
# This is what the object looks like:

# %%
print(neighbor_filter.to_str())
# Out:
# {'dst': ['0fb7390e-a2b2-4855-ac46-bcce5ced9986'],
#  'edge': ['668e63bc-a112-460c-8036-00fc3742ae4c'],
#  'entity_key_ids': ['003b0000-0000-0000-8000-0000000020d7',
#                     '00e40000-0000-0000-8000-00000000207e',
#                     '01140000-0000-0000-8000-000000003159',
#                     '02a80000-0000-0000-8000-0000000020e8',
#                     '03810000-0000-0000-8000-0000000035cb',
#                     '04f20000-0000-0000-8000-000000002076',
#                     '05350000-0000-0000-8000-000000002153',
#                     '05b40000-0000-0000-8000-00000000208f',
#                     '05e40000-0000-0000-8000-000000002071',
#                     '064c0000-0000-0000-8000-0000000031a8'],
#  'src': []}

# %% [markdown]
# Now we can do the filtered search.

# %%
filtered_neighbors = searchAPI.execute_filtered_entity_neighbor_search(
    sourceEntitySetId, 
    neighbor_search_filter=neighbor_filter)

# %% [markdown]
# Here we have an object with as keys the source entity keys (the 10 first we gave above) and as objects the neighbors.

# %%
filtered_neighbors
# Out:
# {'02a80000-0000-0000-8000-0000000020e8': [{'associationEntitySet': {'id': '668e63bc-a112-460c-8036-00fc3742ae4c',
#     'entityTypeId': '2ad709a7-da75-456f-831c-9f263ef9f510',
#     'name': 'DemoLivesAt',
#     'title': 'Demo: LivesAt',
#     'description': '',
#     'contacts': ['kim@openlattice.com', 'jason@openlattice.com'],
#     'linking': False,
#     'linkedEntitySets': [],
#     'external': True,
#     'organization': {'type': 'ORGANIZATION', 'id': 'openlatticeOrg'}},
#    'associationDetails': {'general.id': ['ba086259-551e-4764-be3c-a3a44d34de92_HOMELESS'],
#     'openlattice.@id': ['86c30000-0000-0000-8000-000000003208']},
#    'neighborEntitySet': {'id': '0fb7390e-a2b2-4855-ac46-bcce5ced9986',
#     'entityTypeId': '2fb96971-862a-4cd9-a9bc-00e89436a9d5',
#     'name': 'DemoHousings',
#     'title': 'Demo: Housings',
#     'description': '',
#     'contacts': ['kim@openlattice.com', 'jason@openlattice.com'],
#     'linking': False,
#     'linkedEntitySets': [],
#     'external': True,
#     'organization': {'type': 'ORGANIZATION', 'id': 'openlatticeOrg'}},
#    'neighborId': 'd5000000-0000-0000-8000-000000003234',
#    'neighborDetails': {'ol.id': ['HOMELESS'],
#     'openlattice.@id': ['d5000000-0000-0000-8000-000000003234'],
#     'ol.type': ['HOMELESS']},
#    'src': True}],
#  '064c0000-0000-0000-8000-0000000031a8': [{'associationEntitySet': {'id': '668e63bc-a112-460c-8036-00fc3742ae4c',
#     'entityTypeId': '2ad709a7-da75-456f-831c-9f263ef9f510',
#     'name': 'DemoLivesAt',
#     'title': 'Demo: LivesAt',
#     'description': '',
#     'contacts': ['kim@openlattice.com', 'jason@openlattice.com'],
#     'linking': False,
#     'linkedEntitySets': [],
#     'external': True,
#     'organization': {'type': 'ORGANIZATION', 'id': 'openlatticeOrg'}},
#    'associationDetails': {'general.id': ['ca18962e-a0c1-401f-b171-b2435b696ff2_INDEPENDENT LIVING'],
#     'openlattice.@id': ['f9fd0000-0000-0000-8000-00000000321a']},
#    'neighborEntitySet': {'id': '0fb7390e-a2b2-4855-ac46-bcce5ced9986',
#     'entityTypeId': '2fb96971-862a-4cd9-a9bc-00e89436a9d5',
#     'name': 'DemoHousings',
#     'title': 'Demo: Housings',
#     'description': '',
#     'contacts': ['kim@openlattice.com', 'jason@openlattice.com'],
#     'linking': False,
#     'linkedEntitySets': [],
#     'external': True,
#     'organization': {'type': 'ORGANIZATION', 'id': 'openlatticeOrg'}},
#    'neighborId': 'cef20000-0000-0000-8000-0000000032a9',
#    'neighborDetails': {'ol.id': ['INDEPENDENT LIVING'],
#     'openlattice.@id': ['cef20000-0000-0000-8000-0000000032a9'],
#     'ol.type': ['INDEPENDENT LIVING']},
#    'src': True},
#   {'associationEntitySet': {'id': '668e63bc-a112-460c-8036-00fc3742ae4c',
#     'entityTypeId': '2ad709a7-da75-456f-831c-9f263ef9f510',
#     'name': 'DemoLivesAt',
#     'title': 'Demo: LivesAt',
#     'description': '',
#     'contacts': ['kim@openlattice.com', 'jason@openlattice.com'],
#     'linking': False,
#     'linkedEntitySets': [],
#     'external': True,
#     'organization': {'type': 'ORGANIZATION', 'id': 'openlatticeOrg'}},
#    'associationDetails': {'general.id': ['ca18962e-a0c1-401f-b171-b2435b696ff2_HOMELESS'],
#     'openlattice.@id': ['c13a0000-0000-0000-8000-0000000031c4']},
#    'neighborEntitySet': {'id': '0fb7390e-a2b2-4855-ac46-bcce5ced9986',
#     'entityTypeId': '2fb96971-862a-4cd9-a9bc-00e89436a9d5',
#     'name': 'DemoHousings',
#     'title': 'Demo: Housings',
#     'description': '',
#     'contacts': ['kim@openlattice.com', 'jason@openlattice.com'],
#     'linking': False,
#     'linkedEntitySets': [],
#     'external': True,
#     'organization': {'type': 'ORGANIZATION', 'id': 'openlatticeOrg'}},
#    'neighborId': 'd5000000-0000-0000-8000-000000003234',
#    'neighborDetails': {'ol.id': ['HOMELESS'],
#     'openlattice.@id': ['d5000000-0000-0000-8000-000000003234'],
#     'ol.type': ['HOMELESS']},
#    'src': True},
#   {'associationEntitySet': {'id': '668e63bc-a112-460c-8036-00fc3742ae4c',
#     'entityTypeId': '2ad709a7-da75-456f-831c-9f263ef9f510',
#     'name': 'DemoLivesAt',
#     'title': 'Demo: LivesAt',
#     'description': '',
#     'contacts': ['kim@openlattice.com', 'jason@openlattice.com'],
#     'linking': False,
#     'linkedEntitySets': [],
#     'external': True,
#     'organization': {'type': 'ORGANIZATION', 'id': 'openlatticeOrg'}},
#    'associationDetails': {'general.id': ['ca18962e-a0c1-401f-b171-b2435b696ff2_DEPENDENT LIVING'],
#     'openlattice.@id': ['c7340000-0000-0000-8000-000000003254']},
#    'neighborEntitySet': {'id': '0fb7390e-a2b2-4855-ac46-bcce5ced9986',
#     'entityTypeId': '2fb96971-862a-4cd9-a9bc-00e89436a9d5',
#     'name': 'DemoHousings',
#     'title': 'Demo: Housings',
#     'description': '',
#     'contacts': ['kim@openlattice.com', 'jason@openlattice.com'],
#     'linking': False,
#     'linkedEntitySets': [],
#     'external': True,
#     'organization': {'type': 'ORGANIZATION', 'id': 'openlatticeOrg'}},
#    'neighborId': '34490000-0000-0000-8000-0000000032ee',
#    'neighborDetails': {'ol.id': ['DEPENDENT LIVING'],
#     'openlattice.@id': ['34490000-0000-0000-8000-0000000032ee'],
#     'ol.type': ['DEPENDENT LIVING']},
#    'src': True}]}

# %% [markdown]
# ## Creating the edges table
#
# To recombine the entity sets, we first construct the edges table that holds the keys to join the tables together.

# %%
edges = [
    {
        "src": src_id, 
        "edge": edge['associationDetails']['openlattice.@id'][0],
        "dst": edge['neighborDetails']['openlattice.@id'][0]
    }
 for src_id, edges in filtered_neighbors.items() for edge in edges 
]

edges_table = pd.DataFrame(edges)
edges_table
# Out:
#                                     dst                                  edge  \
# 0  d5000000-0000-0000-8000-000000003234  86c30000-0000-0000-8000-000000003208
# 1  cef20000-0000-0000-8000-0000000032a9  f9fd0000-0000-0000-8000-00000000321a
# 2  d5000000-0000-0000-8000-000000003234  c13a0000-0000-0000-8000-0000000031c4
# 3  34490000-0000-0000-8000-0000000032ee  c7340000-0000-0000-8000-000000003254
#
#                                     src
# 0  02a80000-0000-0000-8000-0000000020e8
# 1  064c0000-0000-0000-8000-0000000031a8
# 2  064c0000-0000-0000-8000-0000000031a8
# 3  064c0000-0000-0000-8000-0000000031a8

# %% [markdown]
# ## Combining the data with the association.
#
# Now we can do left joins on the edges table with the other tables.

# %%
# get data in dataframe
src_data = pd.DataFrame(src_data)
edge_data = pd.DataFrame(edge_data)
dst_data = pd.DataFrame(dst_data)

# %%
recombined = edges_table.merge(
    src_data, 
    left_on='src', 
    right_index = True, 
    how="left"
).merge(
    edge_data, 
    left_on='edge', 
    right_index = True, 
    how="left"
).merge(
    dst_data, 
    left_on='dst', 
    right_index = True, 
    how="left"
)

# %%
recombined.head(5)
# Out:
#                                     dst                                  edge  \
# 0  d5000000-0000-0000-8000-000000003234  86c30000-0000-0000-8000-000000003208
# 1  cef20000-0000-0000-8000-0000000032a9  f9fd0000-0000-0000-8000-00000000321a
# 2  d5000000-0000-0000-8000-000000003234  c13a0000-0000-0000-8000-0000000031c4
# 3  34490000-0000-0000-8000-0000000032ee  c7340000-0000-0000-8000-000000003254
#
#                                     src nc.PersonBirthDate nc.PersonEthnicity  \
# 0  02a80000-0000-0000-8000-0000000020e8         1967-03-20        nonhispanic
# 1  064c0000-0000-0000-8000-0000000031a8         1994-12-12           hispanic
# 2  064c0000-0000-0000-8000-0000000031a8         1994-12-12           hispanic
# 3  064c0000-0000-0000-8000-0000000031a8         1994-12-12           hispanic
#
#   nc.PersonGivenName nc.PersonRace nc.PersonSex nc.PersonSurName  \
# 0             Tamara         asian            F             Koch
# 1            Anthony         other            M  Burton-Johnston
# 2            Anthony         other            M  Burton-Johnston
# 3            Anthony         other            M  Burton-Johnston
#
#                nc.SubjectIdentification                ol.datasource  \
# 0  ba086259-551e-4764-be3c-a3a44d34de92  Forest Outpatient Treatment
# 1  ca18962e-a0c1-401f-b171-b2435b696ff2  Forest Outpatient Treatment
# 2  ca18962e-a0c1-401f-b171-b2435b696ff2  Forest Outpatient Treatment
# 3  ca18962e-a0c1-401f-b171-b2435b696ff2  Forest Outpatient Treatment
#
#                                           general.id               ol.id  \
# 0      ba086259-551e-4764-be3c-a3a44d34de92_HOMELESS            HOMELESS
# 1  ca18962e-a0c1-401f-b171-b2435b696ff2_INDEPENDE...  INDEPENDENT LIVING
# 2      ca18962e-a0c1-401f-b171-b2435b696ff2_HOMELESS            HOMELESS
# 3  ca18962e-a0c1-401f-b171-b2435b696ff2_DEPENDENT...    DEPENDENT LIVING
#
#               ol.type
# 0            HOMELESS
# 1  INDEPENDENT LIVING
# 2            HOMELESS
# 3    DEPENDENT LIVING
